# %%
import polars as pl
import glob
import os

# %%
vcf_dir = "../../data/vcf_filtermutectcalls"
outdir = "../../evaluations/ad_filtered"

# %%
lookup = pl.read_csv("../../annot/sample-info_matched-ff-ffpe_on-pat-id.tsv", separator="\t")
lookup = lookup.with_columns((pl.col("sample_alias") + pl.lit("_") + pl.col("run_accession")).alias("sample_id"))

# %%
ffpe_samples = lookup.filter(pl.col("preservation") == "FFPE")
frozen_samples = lookup.filter(pl.col("preservation") == "Frozen")

# %%
vcf_paths = glob.glob(f"{vcf_dir}/*/*.vcf")

# %%
common_cols = ["chrom", "pos", "ref", "alt"]

intersections = {
    "ffpe_sample_id": [],
    "frozen_sample_id": [],
    "unfiltered_ffpe" : [],
    "unfiltered_frozen" : [],
    "unfiltered_intersection": []
}

for i, ffpe_sample_id in enumerate(ffpe_samples.get_column("sample_id")):
    
    ffpe_vcf = (
        pl.read_csv(f"{vcf_dir}/{ffpe_sample_id}/{ffpe_sample_id}.vcf", 
                    separator="\t", 
                    comment_prefix="##")
        .rename(lambda col_name : col_name.lower().replace("#", ""))
        .rename(lambda col_name : f"{col_name}_ffpe" if col_name not in common_cols else col_name)
    )
    
    frozen_sample_id = frozen_samples.filter(pl.col("inferred_id") == lookup[i, "inferred_id"])[0, "sample_id"]
    
    frozen_vcf = (
        pl.read_csv(f"{vcf_dir}/{frozen_sample_id}/{frozen_sample_id}.vcf", 
                    separator="\t", 
                    comment_prefix="##")
        .rename(lambda col_name : col_name.lower()
        .replace("#", ""))
        .rename(lambda col_name : f"{col_name}_frozen" if col_name not in common_cols else col_name)
    )
    
    intersections["ffpe_sample_id"].append(ffpe_sample_id)
    intersections["frozen_sample_id"].append(frozen_sample_id)
    intersections["unfiltered_ffpe"].append(ffpe_vcf.shape[0])
    intersections["unfiltered_frozen"].append(frozen_vcf.shape[0])
    intersections["unfiltered_intersection"].append(ffpe_vcf.join(frozen_vcf, on=["chrom", "pos", "ref", "alt"], how="semi").shape[0])
    break

# intersections_summary = pl.DataFrame(intersections)

# %%
# intersections_summary.write_csv(f"{outdir}/intersection_count.tsv", separator="\t")
intersections_summary
# Out:
# shape: (14, 5)
# ┌────────────────────┬───────────────────┬─────────────────┬───────────────────┬───────────────────┐
# │ ffpe_sample_id     ┆ frozen_sample_id  ┆ unfiltered_ffpe ┆ unfiltered_frozen ┆ unfiltered_inters │
# │ ---                ┆ ---               ┆ ---             ┆ ---               ┆ ection            │
# │ str                ┆ str               ┆ i64             ┆ i64               ┆ ---               │
# │                    ┆                   ┆                 ┆                   ┆ i64               │
# ╞════════════════════╪═══════════════════╪═════════════════╪═══════════════════╪═══════════════════╡
# │ Pat01_Meta_FFPE_ER ┆ Pat01_Meta_Frozen ┆ 1115            ┆ 511               ┆ 64                │
# │ R791893            ┆ _ERR791883        ┆                 ┆                   ┆                   │
# │ Pat03_Meta_FFPE_ER ┆ Pat01_Meta_Frozen ┆ 905             ┆ 511               ┆ 53                │
# │ R791895            ┆ _ERR791883        ┆                 ┆                   ┆                   │
# │ Pat04_Prim_FFPE_ER ┆ Pat03_Meta_Frozen ┆ 1871            ┆ 754               ┆ 37                │
# │ R791897            ┆ _ERR791884        ┆                 ┆                   ┆                   │
# │ Pat04_Meta_FFPE_ER ┆ Pat03_Meta_Frozen ┆ 622             ┆ 754               ┆ 58                │
# │ R791896            ┆ _ERR791884        ┆                 ┆                   ┆                   │
# │ Pat08_Meta_FFPE_ER ┆ Pat04_Meta_Frozen ┆ 401             ┆ 714               ┆ 34                │
# │ R791901            ┆ _ERR791891        ┆                 ┆                   ┆                   │
# │ …                  ┆ …                 ┆ …               ┆ …                 ┆ …                 │
# │ Pat11_Prim_FFPE_ER ┆ Pat09_Meta_Frozen ┆ 825             ┆ 538               ┆ 56                │
# │ R791906            ┆ _ERR791887        ┆                 ┆                   ┆                   │
# │ Pat12_Meta_FFPE_ER ┆ Pat09_Meta_Frozen ┆ 832             ┆ 538               ┆ 36                │
# │ R791907            ┆ _ERR791887        ┆                 ┆                   ┆                   │
# │ Pat13_Meta_FFPE_ER ┆ Pat10_Meta_Frozen ┆ 663             ┆ 338               ┆ 32                │
# │ R791908            ┆ _ERR791888        ┆                 ┆                   ┆                   │
# │ Pat14_Meta_FFPE_ER ┆ Pat10_Meta_Frozen ┆ 785             ┆ 338               ┆ 46                │
# │ R791909            ┆ _ERR791888        ┆                 ┆                   ┆                   │
# │ Pat14_Prim_FFPE_ER ┆ Pat10_Meta_Frozen ┆ 862             ┆ 338               ┆ 26                │
# │ R791910            ┆ _ERR791888        ┆                 ┆                   ┆                   │
# └────────────────────┴───────────────────┴─────────────────┴───────────────────┴───────────────────┘

# %%
(
    ffpe_vcf.join(frozen_vcf, on=["chrom", "pos", "ref", "alt"], how="inner")
    .select(['chrom','pos','ref','alt','filter_ffpe','filter_frozen','info_ffpe','info_frozen','format_ffpe','format_frozen','err791893_ffpe','err791883_frozen'])
)
# Out:
# shape: (64, 12)
# ┌───────┬───────────┬─────┬─────┬───┬───────────────┬───────────────┬───────────────┬──────────────┐
# │ chrom ┆ pos       ┆ ref ┆ alt ┆ … ┆ format_ffpe   ┆ format_frozen ┆ err791893_ffp ┆ err791883_fr │
# │ ---   ┆ ---       ┆ --- ┆ --- ┆   ┆ ---           ┆ ---           ┆ e             ┆ ozen         │
# │ str   ┆ i64       ┆ str ┆ str ┆   ┆ str           ┆ str           ┆ ---           ┆ ---          │
# │       ┆           ┆     ┆     ┆   ┆               ┆               ┆ str           ┆ str          │
# ╞═══════╪═══════════╪═════╪═════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════════════╡
# │ chr1  ┆ 114713909 ┆ G   ┆ T   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:25,42:0.5 ┆ 0/1:511,40:0 │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ 38:67:23,27:0 ┆ .074:551:481 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ SB            ┆ ,0:2…         ┆ ,38:0,…      │
# │ chr2  ┆ 211665423 ┆ C   ┆ T   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:4255,89:0 ┆ 0/1:9557,49: │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ .017:4344:225 ┆ 2.871e-03:96 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ SB            ┆ 2,38…         ┆ 06:537…      │
# │ chr2  ┆ 211713649 ┆ C   ┆ T   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:601,20:0. ┆ 0/1:3984,10: │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ 016:621:456,1 ┆ 1.682e-03:39 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ SB            ┆ 2:0,…         ┆ 94:260…      │
# │ chr3  ┆ 10146651  ┆ C   ┆ T   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:10844,33: ┆ 0/1:10570,13 │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ 2.989e-03:108 ┆ :1.087e-03:1 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ SB            ┆ 77:5…         ┆ 0583:5…      │
# │ chr3  ┆ 10146652  ┆ T   ┆ C   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:10785,87: ┆ 0/1:10525,56 │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ 7.830e-03:108 ┆ :4.926e-03:1 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ SB            ┆ 72:5…         ┆ 0581:5…      │
# │ …     ┆ …         ┆ …   ┆ …   ┆ … ┆ …             ┆ …             ┆ …             ┆ …            │
# │ chr18 ┆ 51067032  ┆ A   ┆ C   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:6812,15:2 ┆ 0/1:11026,24 │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ .104e-03:6827 ┆ :1.643e-03:1 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ SB            ┆ :359…         ┆ 1050:5…      │
# │ chr18 ┆ 51067034  ┆ A   ┆ G   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:6807,35:4 ┆ 0/1:11004,85 │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ .035e-03:6842 ┆ :4.985e-03:1 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ SB            ┆ :358…         ┆ 1089:5…      │
# │ chr19 ┆ 3119241   ┆ C   ┆ T   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0|1:10,2647:0 ┆ 0/1:12,1856: │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ .996:2657:0,0 ┆ 0.996:1868:0 │
# │       ┆           ┆     ┆     ┆   ┆ PGT:…         ┆ SB            ┆ :9,2…         ┆ ,0:6,1…      │
# │ chr22 ┆ 16574568  ┆ G   ┆ A   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:17,2106:0 ┆ 0|1:46,5408: │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ .992:2123:8,1 ┆ 0.993:5454:2 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ PGT:…         ┆ 051:…         ┆ 2,2877…      │
# │ chr22 ┆ 23801072  ┆ T   ┆ C   ┆ … ┆ GT:AD:AF:DP:F ┆ GT:AD:AF:DP:F ┆ 0/1:6331,23:2 ┆ 0/1:2756,13: │
# │       ┆           ┆     ┆     ┆   ┆ 1R2:F2R1:FAD: ┆ 1R2:F2R1:FAD: ┆ .909e-03:6354 ┆ 3.799e-03:27 │
# │       ┆           ┆     ┆     ┆   ┆ SB            ┆ SB            ┆ :333…         ┆ 69:162…      │
# └───────┴───────────┴─────┴─────┴───┴───────────────┴───────────────┴───────────────┴──────────────┘

# %%
ffpe_vcf.join(frozen_vcf, on=["chrom", "pos", "ref", "alt"], how="semi")
# Out:
# shape: (64, 10)
# ┌───────┬───────────┬─────────┬─────┬───┬──────────────┬──────────────┬──────────────┬─────────────┐
# │ chrom ┆ pos       ┆ id_ffpe ┆ ref ┆ … ┆ filter_ffpe  ┆ info_ffpe    ┆ format_ffpe  ┆ err791893_f │
# │ ---   ┆ ---       ┆ ---     ┆ --- ┆   ┆ ---          ┆ ---          ┆ ---          ┆ fpe         │
# │ str   ┆ i64       ┆ str     ┆ str ┆   ┆ str          ┆ str          ┆ str          ┆ ---         │
# │       ┆           ┆         ┆     ┆   ┆              ┆              ┆              ┆ str         │
# ╞═══════╪═══════════╪═════════╪═════╪═══╪══════════════╪══════════════╪══════════════╪═════════════╡
# │ chr1  ┆ 114713909 ┆ .       ┆ G   ┆ … ┆ PASS         ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:25,42:0 │
# │       ┆           ┆         ┆     ┆   ┆              ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ .538:67:23, │
# │       ┆           ┆         ┆     ┆   ┆              ┆ SB_TAB…      ┆ D:SB         ┆ 27:0,0:2…   │
# │ chr2  ┆ 211665423 ┆ .       ┆ C   ┆ … ┆ clustered_ev ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:4255,89 │
# │       ┆           ┆         ┆     ┆   ┆ ents         ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ :0.017:4344 │
# │       ┆           ┆         ┆     ┆   ┆              ┆ SB_TAB…      ┆ D:SB         ┆ :2252,38…   │
# │ chr2  ┆ 211713649 ┆ .       ┆ C   ┆ … ┆ clustered_ev ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:601,20: │
# │       ┆           ┆         ┆     ┆   ┆ ents         ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ 0.016:621:4 │
# │       ┆           ┆         ┆     ┆   ┆              ┆ SB_TAB…      ┆ D:SB         ┆ 56,12:0,…   │
# │ chr3  ┆ 10146651  ┆ .       ┆ C   ┆ … ┆ clustered_ev ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:10844,3 │
# │       ┆           ┆         ┆     ┆   ┆ ents         ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ 3:2.989e-03 │
# │       ┆           ┆         ┆     ┆   ┆              ┆ SB_TAB…      ┆ D:SB         ┆ :10877:5…   │
# │ chr3  ┆ 10146652  ┆ .       ┆ T   ┆ … ┆ clustered_ev ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:10785,8 │
# │       ┆           ┆         ┆     ┆   ┆ ents         ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ 7:7.830e-03 │
# │       ┆           ┆         ┆     ┆   ┆              ┆ SB_TAB…      ┆ D:SB         ┆ :10872:5…   │
# │ …     ┆ …         ┆ …       ┆ …   ┆ … ┆ …            ┆ …            ┆ …            ┆ …           │
# │ chr18 ┆ 51067032  ┆ .       ┆ A   ┆ … ┆ clustered_ev ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:6812,15 │
# │       ┆           ┆         ┆     ┆   ┆ ents         ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ :2.104e-03: │
# │       ┆           ┆         ┆     ┆   ┆              ┆ SB_TAB…      ┆ D:SB         ┆ 6827:359…   │
# │ chr18 ┆ 51067034  ┆ .       ┆ A   ┆ … ┆ clustered_ev ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:6807,35 │
# │       ┆           ┆         ┆     ┆   ┆ ents         ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ :4.035e-03: │
# │       ┆           ┆         ┆     ┆   ┆              ┆ SB_TAB…      ┆ D:SB         ┆ 6842:358…   │
# │ chr19 ┆ 3119241   ┆ .       ┆ C   ┆ … ┆ clustered_ev ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0|1:10,2647 │
# │       ┆           ┆         ┆     ┆   ┆ ents;germlin ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ :0.996:2657 │
# │       ┆           ┆         ┆     ┆   ┆ e;hapl…      ┆ SB_TAB…      ┆ D:PGT:…      ┆ :0,0:9,2…   │
# │ chr22 ┆ 16574568  ┆ .       ┆ G   ┆ … ┆ germline;pan ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:17,2106 │
# │       ┆           ┆         ┆     ┆   ┆ el_of_normal ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ :0.992:2123 │
# │       ┆           ┆         ┆     ┆   ┆ s            ┆ SB_TAB…      ┆ D:SB         ┆ :8,1051:…   │
# │ chr22 ┆ 23801072  ┆ .       ┆ T   ┆ … ┆ PASS         ┆ AS_FilterSta ┆ GT:AD:AF:DP: ┆ 0/1:6331,23 │
# │       ┆           ┆         ┆     ┆   ┆              ┆ tus=SITE;AS_ ┆ F1R2:F2R1:FA ┆ :2.909e-03: │
# │       ┆           ┆         ┆     ┆   ┆              ┆ SB_TAB…      ┆ D:SB         ┆ 6354:333…   │
# └───────┴───────────┴─────────┴─────┴───┴──────────────┴──────────────┴──────────────┴─────────────┘

# %%
ffpe_vcf.join(frozen_vcf, on=["chrom", "pos", "ref", "alt"], how="anti")
# Out:
# shape: (1_051, 10)
# ┌───────┬───────────┬─────────┬───────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ chrom ┆ pos       ┆ id_ffpe ┆ ref   ┆ … ┆ filter_ffpe  ┆ info_ffpe   ┆ format_ffpe ┆ err791893_f │
# │ ---   ┆ ---       ┆ ---     ┆ ---   ┆   ┆ ---          ┆ ---         ┆ ---         ┆ fpe         │
# │ str   ┆ i64       ┆ str     ┆ str   ┆   ┆ str          ┆ str         ┆ str         ┆ ---         │
# │       ┆           ┆         ┆       ┆   ┆              ┆             ┆             ┆ str         │
# ╞═══════╪═══════════╪═════════╪═══════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ chr1  ┆ 43349363  ┆ .       ┆ C     ┆ … ┆ clustered_ev ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:3144,27 │
# │       ┆           ┆         ┆       ┆   ┆ ents         ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ :6.265e-03: │
# │       ┆           ┆         ┆       ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 3171:226…   │
# │ chr1  ┆ 43349364  ┆ .       ┆ C     ┆ … ┆ clustered_ev ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:3147,23 │
# │       ┆           ┆         ┆       ┆   ┆ ents         ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ :5.158e-03: │
# │       ┆           ┆         ┆       ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 3170:219…   │
# │ chr1  ┆ 43349367  ┆ .       ┆ CCCCG ┆ … ┆ clustered_ev ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:3161,11 │
# │       ┆           ┆         ┆       ┆   ┆ ents         ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ :3.391e-03: │
# │       ┆           ┆         ┆       ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 3172:232…   │
# │ chr1  ┆ 43349375  ┆ .       ┆ G     ┆ … ┆ clustered_ev ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:3160,12 │
# │       ┆           ┆         ┆       ┆   ┆ ents         ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ :3.015e-03: │
# │       ┆           ┆         ┆       ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 3172:241…   │
# │ chr1  ┆ 107236445 ┆ .       ┆ A     ┆ … ┆ PASS         ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:26,2:0. │
# │       ┆           ┆         ┆       ┆   ┆              ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ 125:28:13,1 │
# │       ┆           ┆         ┆       ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ :0,0:13,…   │
# │ …     ┆ …         ┆ …       ┆ …     ┆ … ┆ …            ┆ …           ┆ …           ┆ …           │
# │ chr22 ┆ 26100281  ┆ .       ┆ C     ┆ … ┆ PASS         ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:0,4:0.7 │
# │       ┆           ┆         ┆       ┆   ┆              ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ 50:4:0,2:0, │
# │       ┆           ┆         ┆       ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 0:0,2:0,…   │
# │ chr22 ┆ 37236545  ┆ .       ┆ T     ┆ … ┆ PASS         ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:18,8:0. │
# │       ┆           ┆         ┆       ┆   ┆              ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ 333:26:0,0: │
# │       ┆           ┆         ┆       ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 9,4:9,4:…   │
# │ chrY  ┆ 19156591  ┆ .       ┆ CAA   ┆ … ┆ clustered_ev ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1/2:13,3, │
# │       ┆           ┆         ┆       ┆   ┆ ents;multial ┆ atus=weak_e ┆ :F1R2:F2R1: ┆ 5:0.172,0.2 │
# │       ┆           ┆         ┆       ┆   ┆ lelic        ┆ vidence|…   ┆ FAD:SB      ┆ 62:21:0,…   │
# │ chrY  ┆ 19156600  ┆ .       ┆ A     ┆ … ┆ clustered_ev ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0|1:19,2:0. │
# │       ┆           ┆         ┆       ┆   ┆ ents;haploty ┆ atus=weak_e ┆ :F1R2:F2R1: ┆ 133:21:0,0: │
# │       ┆           ┆         ┆       ┆   ┆ pe;wea…      ┆ vidence;…   ┆ FAD:PGT:…   ┆ 12,1:12,…   │
# │ chrY  ┆ 19156608  ┆ .       ┆ A     ┆ … ┆ clustered_ev ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 1|0:19,2:0. │
# │       ┆           ┆         ┆       ┆   ┆ ents;haploty ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ 133:21:0,0: │
# │       ┆           ┆         ┆       ┆   ┆ pe           ┆ S_SB_TAB…   ┆ FAD:PGT:…   ┆ 12,1:12,…   │
# └───────┴───────────┴─────────┴───────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘

# %%
frozen_vcf.join(ffpe_vcf, on=["chrom", "pos", "ref", "alt"], how="anti")
# Out:
# shape: (447, 10)
# ┌───────┬───────────┬───────────┬─────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ chrom ┆ pos       ┆ id_frozen ┆ ref ┆ … ┆ filter_froze ┆ info_frozen ┆ format_froz ┆ err791883_f │
# │ ---   ┆ ---       ┆ ---       ┆ --- ┆   ┆ n            ┆ ---         ┆ en          ┆ rozen       │
# │ str   ┆ i64       ┆ str       ┆ str ┆   ┆ ---          ┆ str         ┆ ---         ┆ ---         │
# │       ┆           ┆           ┆     ┆   ┆ str          ┆             ┆ str         ┆ str         │
# ╞═══════╪═══════════╪═══════════╪═════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ chr1  ┆ 60897254  ┆ .         ┆ A   ┆ … ┆ PASS         ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:0,2:0.6 │
# │       ┆           ┆           ┆     ┆   ┆              ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ 67:2:0,1:0, │
# │       ┆           ┆           ┆     ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 0:0,1:0,…   │
# │ chr1  ┆ 110658498 ┆ .         ┆ C   ┆ … ┆ PASS         ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:0,1:0.6 │
# │       ┆           ┆           ┆     ┆   ┆              ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ 67:1:0,0:0, │
# │       ┆           ┆           ┆     ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 1:0,1:0,…   │
# │ chr1  ┆ 114716138 ┆ .         ┆ A   ┆ … ┆ base_qual;ha ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0|1:7346,31 │
# │       ┆           ┆           ┆     ┆   ┆ plotype;stra ┆ atus=base_q ┆ :F1R2:F2R1: ┆ :1.209e-03: │
# │       ┆           ┆           ┆     ┆   ┆ nd_bia…      ┆ ual,stra…   ┆ FAD:PGT:…   ┆ 7377:509…   │
# │ chr1  ┆ 114716146 ┆ .         ┆ T   ┆ … ┆ strand_bias  ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 1|0:7423,28 │
# │       ┆           ┆           ┆     ┆   ┆              ┆ atus=strand ┆ :F1R2:F2R1: ┆ :1.537e-03: │
# │       ┆           ┆           ┆     ┆   ┆              ┆ _bias;AS…   ┆ FAD:PGT:…   ┆ 7451:505…   │
# │ chr1  ┆ 114716199 ┆ .         ┆ G   ┆ … ┆ strand_bias  ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:8474,83 │
# │       ┆           ┆           ┆     ┆   ┆              ┆ atus=strand ┆ :F1R2:F2R1: ┆ :3.555e-03: │
# │       ┆           ┆           ┆     ┆   ┆              ┆ _bias;AS…   ┆ FAD:SB      ┆ 8557:495…   │
# │ …     ┆ …         ┆ …         ┆ …   ┆ … ┆ …            ┆ …           ┆ …           ┆ …           │
# │ chr22 ┆ 23791857  ┆ .         ┆ A   ┆ … ┆ base_qual;cl ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:6720,98 │
# │       ┆           ┆           ┆     ┆   ┆ ustered_even ┆ atus=base_q ┆ :F1R2:F2R1: ┆ :3.247e-03: │
# │       ┆           ┆           ┆     ┆   ┆ ts           ┆ ual;AS_S…   ┆ FAD:SB      ┆ 6818:395…   │
# │ chr22 ┆ 23791898  ┆ .         ┆ C   ┆ … ┆ clustered_ev ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:6882,29 │
# │       ┆           ┆           ┆     ┆   ┆ ents         ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ :3.721e-03: │
# │       ┆           ┆           ┆     ┆   ┆              ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 6911:388…   │
# │ chr22 ┆ 23803488  ┆ .         ┆ G   ┆ … ┆ germline;pan ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:1,3752: │
# │       ┆           ┆           ┆     ┆   ┆ el_of_normal ┆ atus=SITE;A ┆ :F1R2:F2R1: ┆ 1.000:3753: │
# │       ┆           ┆           ┆     ┆   ┆ s            ┆ S_SB_TAB…   ┆ FAD:SB      ┆ 0,2317:0…   │
# │ chr22 ┆ 23803507  ┆ .         ┆ T   ┆ … ┆ base_qual    ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:3695,30 │
# │       ┆           ┆           ┆     ┆   ┆              ┆ atus=base_q ┆ :F1R2:F2R1: ┆ :3.089e-03: │
# │       ┆           ┆           ┆     ┆   ┆              ┆ ual;AS_S…   ┆ FAD:SB      ┆ 3725:205…   │
# │ chr22 ┆ 23834297  ┆ .         ┆ T   ┆ … ┆ strand_bias  ┆ AS_FilterSt ┆ GT:AD:AF:DP ┆ 0/1:1273,12 │
# │       ┆           ┆           ┆     ┆   ┆              ┆ atus=strand ┆ :F1R2:F2R1: ┆ :5.571e-03: │
# │       ┆           ┆           ┆     ┆   ┆              ┆ _bias;AS…   ┆ FAD:SB      ┆ 1285:29,…   │
# └───────┴───────────┴───────────┴─────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘
